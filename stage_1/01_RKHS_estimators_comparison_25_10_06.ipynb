# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import copy
from matplotlib.lines import Line2D 
from scipy.stats import norm

# %%
def plot_mse(df_mse, UorV=['U'], kernel=['rbf'], estimator=['ipr', 'nrm'], col="facet_blocks", col_wrap=3):
    g = sns.catplot(data=df_mse[(df_mse['kernel'].isin(kernel)) & (df_mse['type'].isin(UorV)) & (df_mse['estimator'].isin(estimator))],
        x="x",   
        y="MSE", 
        hue="method_name",
        palette='tab20', 
        col=col, 
        kind="bar",
        height=4,
        aspect=1.2,
        sharey=False,
        sharex=False,
        col_wrap=col_wrap
    )
    g.set_titles("{col_name}")
    plt.show()

# %% [markdown]
# # RESULTS

# %% [markdown]
# ## Standard comparison

# %%
df_mse = pd.read_csv('results/results_standard_mse_ipr_new.csv', index_col=0)

# %% [markdown]
# ### Figure 1

# %%
plot_mse(df_mse, ['U', 'V'], ['rbf'], ['ipr', 'nrm'])

# %% [markdown]
# ### Figure 1A (NRM)

# %%
df_mse_nrm = pd.read_csv('results/results_standard_mse_nrm_new.csv', index_col=0)
plot_mse(df_mse_nrm, ['U', 'V'], ['rbf'], ['ipr', 'nrm'])

# %% [markdown]
# ### Figure 2

# %%
df_mse = pd.read_csv('results/results_standard_mse_ipr_new.csv', index_col=0)

# %%
plot_mse(df_mse, ['U', 'V'], ['laplacian'], ['ipr', 'nrm'])

# %% [markdown]
# ### Figure 3

# %%
plot_mse(df_mse, ['U'], ['rbf', 'laplacian'], ['ipr'])

# %% [markdown]
# ### Figure 4

# %%
plot_mse(df_mse, ['V'], ['rbf', 'laplacian'], ['ipr'])

# %% [markdown]
# ### Table 1

# %%
df_mse = pd.read_csv('results/results_standard_mse_new.csv', index_col=0)

# %%
df_mse_tmp = copy.copy(df_mse)
df_mse_tmp = df_mse_tmp.loc[df_mse_tmp['n_target'] <= 500,:]

# %%
df_mse_tmp['rank']=df_mse_tmp.groupby(['sim_scenario','n_plus','n_minus','n_target','pi_target']).rank(method='dense', ascending=True)['MSE']

# %%
df_mse_tmp[['method_name', 'rank', 'count_sim']].groupby(['method_name']).agg('mean').reset_index().sort_values('rank').reset_index(drop=True)
# Out:
#                       method_name       rank  count_sim
# 0                  ipr_U_grid_rbf   7.311111      100.0
# 1             ipr_U_numerical_rbf   7.344444      100.0
# 2              ipr_V_distance_rbf   8.211111      100.0
# 3              nrm_V_distance_rbf  10.466667      100.0
# 4        ipr_V_distance_laplacian  10.475000      100.0
# 5      ipr_V_one_over_p_laplacian  11.837500      100.0
# 6       ipr_U_numerical_laplacian  12.050000      100.0
# 7            ipr_U_grid_laplacian  12.275000      100.0
# 8      ipr_U_one_over_p_laplacian  12.325000      100.0
# 9            ipr_V_one_over_p_rbf  13.066667      100.0
# 10                 nrm_U_grid_rbf  13.344444      100.0
# 11            nrm_U_numerical_rbf  13.455556      100.0
# 12        ipr_U_bootstrap_mse_rbf  14.577778      100.0
# 13           ipr_U_one_over_p_rbf  15.000000      100.0
# 14       nrm_V_distance_laplacian  17.237500      100.0
# 15  ipr_U_bootstrap_mse_laplacian  17.462500      100.0
# 16      nrm_U_numerical_laplacian  18.662500      100.0
# 17           nrm_U_grid_laplacian  18.737500      100.0
# 18     nrm_U_one_over_p_laplacian  19.050000      100.0
# 19           nrm_V_one_over_p_rbf  19.855556      100.0
# 20        nrm_U_bootstrap_mse_rbf  19.944444      100.0
# 21     nrm_V_one_over_p_laplacian  20.237500      100.0
# 22       ipr_U_distance_laplacian  20.300000      100.0
# 23            nrm_V_numerical_rbf  20.888889      100.0
# 24           nrm_U_one_over_p_rbf  22.600000      100.0
# 25  nrm_U_bootstrap_mse_laplacian  22.800000      100.0
# 26             ipr_U_distance_rbf  23.255556      100.0
# 27            ipr_V_numerical_rbf  23.744444      100.0
# 28        nrm_V_bootstrap_mse_rbf  25.300000      100.0
# 29        ipr_U_bootstrap_var_rbf  25.433333      100.0
# 30       nrm_U_distance_laplacian  26.475000      100.0
# 31  ipr_U_bootstrap_var_laplacian  27.100000      100.0
# 32                 nrm_V_grid_rbf  28.433333      100.0
# 33             nrm_U_distance_rbf  28.600000      100.0
# 34  nrm_V_bootstrap_mse_laplacian  29.550000      100.0
# 35        nrm_V_bootstrap_var_rbf  31.044444      100.0
# 36        ipr_V_bootstrap_mse_rbf  31.111111      100.0
# 37  nrm_U_bootstrap_var_laplacian  33.150000      100.0
# 38      nrm_V_numerical_laplacian  33.625000      100.0
# 39  nrm_V_bootstrap_var_laplacian  33.987500      100.0
# 40                 ipr_V_grid_rbf  34.022222      100.0
# 41           nrm_V_grid_laplacian  34.312500      100.0
# 42        nrm_U_bootstrap_var_rbf  34.433333      100.0
# 43        ipr_V_bootstrap_var_rbf  35.777778      100.0
# 44  ipr_V_bootstrap_mse_laplacian  36.812500      100.0
# 45      ipr_V_numerical_laplacian  39.650000      100.0
# 46           ipr_V_grid_laplacian  40.150000      100.0
# 47  ipr_V_bootstrap_var_laplacian  40.187500      100.0

# %% [markdown]
# ### Tables 2 and 3

# %%
df_tmp = df_mse_tmp[['method_name', 'pi_target', 'rank', 'count_sim']].groupby(['method_name', 'pi_target']).agg('mean').reset_index().sort_values('rank').reset_index(drop=True)

# %%
df_tmp[df_tmp['pi_target'] == 0.25]
# Out:
#                       method_name  pi_target       rank  count_sim
# 1      ipr_V_one_over_p_laplacian       0.25   4.225000      100.0
# 2                  ipr_U_grid_rbf       0.25   4.800000      100.0
# 3             ipr_U_numerical_rbf       0.25   5.222222      100.0
# 4              ipr_V_distance_rbf       0.25   5.577778      100.0
# 5        ipr_V_distance_laplacian       0.25   5.825000      100.0
# 6            ipr_V_one_over_p_rbf       0.25   5.911111      100.0
# 10           ipr_U_grid_laplacian       0.25   7.800000      100.0
# 11      ipr_U_numerical_laplacian       0.25   7.900000      100.0
# 13     ipr_U_one_over_p_laplacian       0.25   8.800000      100.0
# 17        ipr_U_bootstrap_mse_rbf       0.25  10.377778      100.0
# 20           ipr_U_one_over_p_rbf       0.25  11.133333      100.0
# 21  ipr_U_bootstrap_mse_laplacian       0.25  12.200000      100.0
# 22             nrm_V_distance_rbf       0.25  12.222222      100.0
# 23       ipr_U_distance_laplacian       0.25  14.950000      100.0
# 26                 nrm_U_grid_rbf       0.25  16.155556      100.0
# 32            nrm_U_numerical_rbf       0.25  16.800000      100.0
# 34            ipr_V_numerical_rbf       0.25  17.266667      100.0
# 35        nrm_U_bootstrap_mse_rbf       0.25  17.733333      100.0
# 36             ipr_U_distance_rbf       0.25  18.400000      100.0
# 41        ipr_U_bootstrap_var_rbf       0.25  20.044444      100.0
# 43           nrm_U_grid_laplacian       0.25  20.700000      100.0
# 44  ipr_U_bootstrap_var_laplacian       0.25  20.775000      100.0
# 45      nrm_U_numerical_laplacian       0.25  21.025000      100.0
# 46     nrm_U_one_over_p_laplacian       0.25  21.825000      100.0
# 49  nrm_U_bootstrap_mse_laplacian       0.25  22.250000      100.0
# 56        nrm_V_bootstrap_mse_rbf       0.25  25.288889      100.0
# 60           nrm_U_one_over_p_rbf       0.25  26.022222      100.0
# 61       nrm_V_distance_laplacian       0.25  26.900000      100.0
# 62       nrm_U_distance_laplacian       0.25  26.950000      100.0
# 63        ipr_V_bootstrap_mse_rbf       0.25  27.422222      100.0
# 66             nrm_U_distance_rbf       0.25  29.133333      100.0
# 68                 ipr_V_grid_rbf       0.25  30.355556      100.0
# 70        ipr_V_bootstrap_var_rbf       0.25  32.733333      100.0
# 72  nrm_U_bootstrap_var_laplacian       0.25  33.325000      100.0
# 74  ipr_V_bootstrap_mse_laplacian       0.25  33.475000      100.0
# 75           nrm_V_one_over_p_rbf       0.25  33.600000      100.0
# 77  nrm_V_bootstrap_mse_laplacian       0.25  34.175000      100.0
# 79        nrm_U_bootstrap_var_rbf       0.25  35.111111      100.0
# 80            nrm_V_numerical_rbf       0.25  35.111111      100.0
# 81      ipr_V_numerical_laplacian       0.25  37.050000      100.0
# 82     nrm_V_one_over_p_laplacian       0.25  37.475000      100.0
# 84           ipr_V_grid_laplacian       0.25  37.700000      100.0
# 85  ipr_V_bootstrap_var_laplacian       0.25  37.750000      100.0
# 87                 nrm_V_grid_rbf       0.25  39.777778      100.0
# 89        nrm_V_bootstrap_var_rbf       0.25  40.244444      100.0
# 93      nrm_V_numerical_laplacian       0.25  44.000000      100.0
# 94  nrm_V_bootstrap_var_laplacian       0.25  44.250000      100.0
# 95           nrm_V_grid_laplacian       0.25  44.850000      100.0

# %%
df_tmp[df_tmp['pi_target'] == 0.75]
# Out:
#                       method_name  pi_target       rank  count_sim
# 0      nrm_V_one_over_p_laplacian       0.75   3.000000      100.0
# 7            nrm_V_one_over_p_rbf       0.75   6.111111      100.0
# 8             nrm_V_numerical_rbf       0.75   6.666667      100.0
# 9        nrm_V_distance_laplacian       0.75   7.575000      100.0
# 12             nrm_V_distance_rbf       0.75   8.711111      100.0
# 14            ipr_U_numerical_rbf       0.75   9.466667      100.0
# 15                 ipr_U_grid_rbf       0.75   9.822222      100.0
# 16            nrm_U_numerical_rbf       0.75  10.111111      100.0
# 18                 nrm_U_grid_rbf       0.75  10.533333      100.0
# 19             ipr_V_distance_rbf       0.75  10.844444      100.0
# 24       ipr_V_distance_laplacian       0.75  15.125000      100.0
# 25     ipr_U_one_over_p_laplacian       0.75  15.850000      100.0
# 27      ipr_U_numerical_laplacian       0.75  16.200000      100.0
# 28     nrm_U_one_over_p_laplacian       0.75  16.275000      100.0
# 29      nrm_U_numerical_laplacian       0.75  16.300000      100.0
# 30           ipr_U_grid_laplacian       0.75  16.750000      100.0
# 31           nrm_U_grid_laplacian       0.75  16.775000      100.0
# 33                 nrm_V_grid_rbf       0.75  17.088889      100.0
# 37        ipr_U_bootstrap_mse_rbf       0.75  18.777778      100.0
# 38           ipr_U_one_over_p_rbf       0.75  18.866667      100.0
# 39           nrm_U_one_over_p_rbf       0.75  19.177778      100.0
# 40     ipr_V_one_over_p_laplacian       0.75  19.450000      100.0
# 42           ipr_V_one_over_p_rbf       0.75  20.222222      100.0
# 47        nrm_V_bootstrap_var_rbf       0.75  21.844444      100.0
# 48        nrm_U_bootstrap_mse_rbf       0.75  22.155556      100.0
# 50  ipr_U_bootstrap_mse_laplacian       0.75  22.725000      100.0
# 51      nrm_V_numerical_laplacian       0.75  23.250000      100.0
# 52  nrm_U_bootstrap_mse_laplacian       0.75  23.350000      100.0
# 53  nrm_V_bootstrap_var_laplacian       0.75  23.725000      100.0
# 54           nrm_V_grid_laplacian       0.75  23.775000      100.0
# 55  nrm_V_bootstrap_mse_laplacian       0.75  24.925000      100.0
# 57        nrm_V_bootstrap_mse_rbf       0.75  25.311111      100.0
# 58       ipr_U_distance_laplacian       0.75  25.650000      100.0
# 59       nrm_U_distance_laplacian       0.75  26.000000      100.0
# 64             nrm_U_distance_rbf       0.75  28.066667      100.0
# 65             ipr_U_distance_rbf       0.75  28.111111      100.0
# 67            ipr_V_numerical_rbf       0.75  30.222222      100.0
# 69        ipr_U_bootstrap_var_rbf       0.75  30.822222      100.0
# 71  nrm_U_bootstrap_var_laplacian       0.75  32.975000      100.0
# 73  ipr_U_bootstrap_var_laplacian       0.75  33.425000      100.0
# 76        nrm_U_bootstrap_var_rbf       0.75  33.755556      100.0
# 78        ipr_V_bootstrap_mse_rbf       0.75  34.800000      100.0
# 83                 ipr_V_grid_rbf       0.75  37.688889      100.0
# 86        ipr_V_bootstrap_var_rbf       0.75  38.822222      100.0
# 88  ipr_V_bootstrap_mse_laplacian       0.75  40.150000      100.0
# 90      ipr_V_numerical_laplacian       0.75  42.250000      100.0
# 91           ipr_V_grid_laplacian       0.75  42.600000      100.0
# 92  ipr_V_bootstrap_var_laplacian       0.75  42.625000      100.0

# %% [markdown]
# ### Figure 5

# %%
plot_mse(df_mse, ['U', 'V'], ['rbf', 'laplacian'], ['ipr'])

# %% [markdown]
# ## Dimension

# %%
df_mse = pd.read_csv('results/results_dimension_mse_new.csv', index_col=0)

# %% [markdown]
# ### Figure 6

# %%
plot_mse(df_mse, ['U'])

# %% [markdown]
# ### Figure 7

# %%
plot_mse(df_mse, ['V'])

# %% [markdown]
# ### Figure 8

# %%
plot_mse(df_mse, ['U', 'V'], estimator=['ipr'])

# %% [markdown]
# ## Heavy tail distribution

# %%
df_mse = pd.read_csv('results/results_heavy_tail_mse_new.csv', index_col=0)

# %% [markdown]
# ### Figure 9

# %%
plot_mse(df_mse, ['U', 'V'], col_wrap=4)

# %% [markdown]
# # TIME

# %%
df = pd.read_csv('results/results_standard_all.csv', index_col=0)

# %%
df['log_time'] = np.log(df['time'])

# %%
df = df.sort_values(by=["pi_target", "sim_scenario"])
df['facet_blocks'] = df['sim_scenario'] + ", pi_target = " + df['pi_target'].astype(str)

# %%
g = sns.catplot(data=df,
    x="x",  
    y="log_time",              
    hue="method_name",
    palette='tab20',
    col="facet_blocks",         
    kind="bar",
    height=10,
    # aspect=1.2,
    sharey=False,
    sharex=False,
    col_wrap=3
)
g.set_titles("{col_name}")
plt.show()

# %%
# df_time = df[(df['sim_scenario'] == 'sim_par_1') & (df['pi_target'] == 0.25)]

# %%
# df_time = df_time[['time', 'gamma_selection_name', 'type', 'n_target', 'estimator', 'kernel']].groupby(['gamma_selection_name', 'type', 'n_target', 'estimator', 'kernel']).agg('mean').reset_index()

# %%
# df_time['my_time'] = np.nan
# df_time.loc[df_time['gamma_selection_name'] == 'one_over_p', 'my_time'] = 1
# df_time.loc[df_time['gamma_selection_name'] == 'grid', 'my_time'] = 13 + 1
# df_time.loc[df_time['gamma_selection_name'] == 'bootstrap_var', 'my_time'] = 13*50 + 1
# df_time.loc[df_time['gamma_selection_name'] == 'bootstrap_mse', 'my_time'] = 13*50 + 50 + 1
# df_time.loc[df_time['gamma_selection_name'] == 'distance', 'my_time'] = 13 + 1

# %%
# for i in range(len(df_time)):
#     df_time['my_time'] = df_time['my_time']

# %%
# df_time['my_time'] = df_time['my_time']*0.03903

# %%
# df_time.loc[df_time['gamma_selection_name'] == 'one_over_p', 'time']

# %%
# sns.scatterplot(df_time, x='my_time', y='time')
