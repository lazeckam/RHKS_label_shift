# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import copy
from matplotlib.lines import Line2D 
from scipy.stats import norm

# %%
def plot_mse(df_mse, UorV=['U'], kernel=['rbf'], estimator=['ipr', 'nrm'], col="facet_blocks", col_wrap=3):
    g = sns.catplot(data=df_mse[(df_mse['kernel'].isin(kernel)) & (df_mse['type'].isin(UorV)) & (df_mse['estimator'].isin(estimator))],
        x="x",   
        y="MSE", 
        hue="method_name",
        palette='tab20', 
        col=col, 
        kind="bar",
        height=4,
        aspect=1.2,
        sharey=False,
        sharex=False,
        col_wrap=col_wrap
    )
    g.set_titles("{col_name}")
    plt.show()

# %% [markdown]
# # RESULTS

# %% [markdown]
# ## Standard comparison

# %%
df_mse = pd.read_csv('results/results_standard_mse_ipr_new.csv', index_col=0)

# %% [markdown]
# ### Figure 1

# %%
plot_mse(df_mse, ['U', 'V'], ['rbf'], ['ipr', 'nrm'])

# %% [markdown]
# ### Figure 1A (NRM)

# %%
df_mse_nrm = pd.read_csv('results/results_standard_mse_nrm_new.csv', index_col=0)
plot_mse(df_mse_nrm, ['U', 'V'], ['rbf'], ['ipr', 'nrm'])

# %% [markdown]
# ### Figure 2

# %%
df_mse = pd.read_csv('results/results_standard_mse_ipr_new.csv', index_col=0)

# %%
plot_mse(df_mse, ['U', 'V'], ['laplacian'], ['ipr', 'nrm'])

# %% [markdown]
# ### Figure 3

# %%
df_mse = pd.read_csv('results/results_standard_mse_ipr_new.csv', index_col=0)

# %%
plot_mse(df_mse, ['U'], ['rbf', 'laplacian'], ['ipr'])

# %% [markdown]
# ### Figure 4

# %%
plot_mse(df_mse, ['V'], ['rbf', 'laplacian'], ['ipr'])

# %% [markdown]
# ### Figure nightmare

# %%
df_mse = pd.read_csv('results/results_standard_mse_new.csv', index_col=0)

# %%
df_mse = df_mse[~df_mse['gamma_selection_name'].isin(['distance', 'numerical'])]

# %%
plot_mse(df_mse, ["U", 'V'], ['rbf', 'laplacian'], ['ipr', 'nrm'])

# %% [markdown]
# ### Table 1

# %%
df_mse = pd.read_csv('results/results_standard_mse_new.csv', index_col=0)

# %%
df_mse = df_mse[~df_mse['gamma_selection_name'].isin(['distance', 'numerical'])]

# %%
df_mse_tmp = copy.copy(df_mse)
df_mse_tmp = df_mse_tmp.loc[df_mse_tmp['n_target'] <= 500,:]

# %%
df_mse_tmp['rank']=df_mse_tmp.groupby(['sim_scenario','n_plus','n_minus','n_target','pi_target']).rank(method='dense', ascending=True)['MSE']

# %%
df_mse_tmp[['method_name', 'rank', 'count_sim']].groupby(['method_name']).agg('mean').reset_index().sort_values('rank').reset_index(drop=True)
# Out:
#                       method_name       rank  count_sim
# 0                  ipr_U_grid_rbf   4.266667      100.0
# 1      ipr_V_one_over_p_laplacian   6.877778      100.0
# 2      ipr_U_one_over_p_laplacian   6.922222      100.0
# 3            ipr_U_grid_laplacian   6.944444      100.0
# 4                  nrm_U_grid_rbf   8.077778      100.0
# 5            ipr_V_one_over_p_rbf   8.088889      100.0
# 6         ipr_U_bootstrap_mse_rbf   9.155556      100.0
# 7            ipr_U_one_over_p_rbf   9.422222      100.0
# 8   ipr_U_bootstrap_mse_laplacian  10.600000      100.0
# 9            nrm_U_grid_laplacian  11.111111      100.0
# 10     nrm_U_one_over_p_laplacian  11.155556      100.0
# 11        nrm_U_bootstrap_mse_rbf  12.777778      100.0
# 12           nrm_V_one_over_p_rbf  12.788889      100.0
# 13     nrm_V_one_over_p_laplacian  12.833333      100.0
# 14  nrm_U_bootstrap_mse_laplacian  13.933333      100.0
# 15           nrm_U_one_over_p_rbf  14.544444      100.0
# 16        ipr_U_bootstrap_var_rbf  16.488889      100.0
# 17  ipr_U_bootstrap_var_laplacian  16.522222      100.0
# 18        nrm_V_bootstrap_mse_rbf  16.755556      100.0
# 19  nrm_V_bootstrap_mse_laplacian  18.977778      100.0
# 20                 nrm_V_grid_rbf  19.288889      100.0
# 21        ipr_V_bootstrap_mse_rbf  20.166667      100.0
# 22  nrm_U_bootstrap_var_laplacian  20.222222      100.0
# 23        nrm_V_bootstrap_var_rbf  21.133333      100.0
# 24  nrm_V_bootstrap_var_laplacian  22.444444      100.0
# 25           nrm_V_grid_laplacian  22.688889      100.0
# 26                 ipr_V_grid_rbf  22.733333      100.0
# 27        nrm_U_bootstrap_var_rbf  22.955556      100.0
# 28  ipr_V_bootstrap_mse_laplacian  23.577778      100.0
# 29        ipr_V_bootstrap_var_rbf  24.122222      100.0
# 30           ipr_V_grid_laplacian  26.088889      100.0
# 31  ipr_V_bootstrap_var_laplacian  26.122222      100.0

# %% [markdown]
# ### Tables 2 and 3

# %%
df_tmp = df_mse_tmp[['method_name', 'pi_target', 'rank', 'count_sim']].groupby(['method_name', 'pi_target']).agg('mean').reset_index().sort_values('rank').reset_index(drop=True)

# %%
df_tmp[df_tmp['pi_target'] == 0.25].reset_index(drop=True)
# Out:
#                       method_name  pi_target       rank  count_sim
# 0      ipr_V_one_over_p_laplacian       0.25   2.644444      100.0
# 1                  ipr_U_grid_rbf       0.25   2.933333      100.0
# 2            ipr_V_one_over_p_rbf       0.25   3.666667      100.0
# 3            ipr_U_grid_laplacian       0.25   4.311111      100.0
# 4      ipr_U_one_over_p_laplacian       0.25   4.866667      100.0
# 5         ipr_U_bootstrap_mse_rbf       0.25   6.533333      100.0
# 6            ipr_U_one_over_p_rbf       0.25   7.000000      100.0
# 7   ipr_U_bootstrap_mse_laplacian       0.25   7.577778      100.0
# 8                  nrm_U_grid_rbf       0.25  10.377778      100.0
# 9         nrm_U_bootstrap_mse_rbf       0.25  11.355556      100.0
# 10           nrm_U_grid_laplacian       0.25  12.555556      100.0
# 11  ipr_U_bootstrap_var_laplacian       0.25  12.666667      100.0
# 12        ipr_U_bootstrap_var_rbf       0.25  12.888889      100.0
# 13     nrm_U_one_over_p_laplacian       0.25  13.088889      100.0
# 14  nrm_U_bootstrap_mse_laplacian       0.25  13.577778      100.0
# 15        nrm_V_bootstrap_mse_rbf       0.25  16.600000      100.0
# 16           nrm_U_one_over_p_rbf       0.25  16.888889      100.0
# 17        ipr_V_bootstrap_mse_rbf       0.25  17.422222      100.0
# 18                 ipr_V_grid_rbf       0.25  19.777778      100.0
# 19  nrm_U_bootstrap_var_laplacian       0.25  20.355556      100.0
# 20  ipr_V_bootstrap_mse_laplacian       0.25  21.244444      100.0
# 21  nrm_V_bootstrap_mse_laplacian       0.25  21.488889      100.0
# 22        ipr_V_bootstrap_var_rbf       0.25  21.622222      100.0
# 23           nrm_V_one_over_p_rbf       0.25  22.000000      100.0
# 24        nrm_U_bootstrap_var_rbf       0.25  23.777778      100.0
# 25     nrm_V_one_over_p_laplacian       0.25  23.822222      100.0
# 26           ipr_V_grid_laplacian       0.25  24.155556      100.0
# 27  ipr_V_bootstrap_var_laplacian       0.25  24.200000      100.0
# 28                 nrm_V_grid_rbf       0.25  27.533333      100.0
# 29        nrm_V_bootstrap_var_rbf       0.25  27.955556      100.0
# 30  nrm_V_bootstrap_var_laplacian       0.25  29.422222      100.0
# 31           nrm_V_grid_laplacian       0.25  29.866667      100.0

# %%
df_tmp[df_tmp['pi_target'] == 0.75].reset_index(drop=True)
# Out:
#                       method_name  pi_target       rank  count_sim
# 0      nrm_V_one_over_p_laplacian       0.75   1.844444      100.0
# 1            nrm_V_one_over_p_rbf       0.75   3.577778      100.0
# 2                  ipr_U_grid_rbf       0.75   5.600000      100.0
# 3                  nrm_U_grid_rbf       0.75   5.777778      100.0
# 4      ipr_U_one_over_p_laplacian       0.75   8.977778      100.0
# 5      nrm_U_one_over_p_laplacian       0.75   9.222222      100.0
# 6            ipr_U_grid_laplacian       0.75   9.577778      100.0
# 7            nrm_U_grid_laplacian       0.75   9.666667      100.0
# 8                  nrm_V_grid_rbf       0.75  11.044444      100.0
# 9      ipr_V_one_over_p_laplacian       0.75  11.111111      100.0
# 10        ipr_U_bootstrap_mse_rbf       0.75  11.777778      100.0
# 11           ipr_U_one_over_p_rbf       0.75  11.844444      100.0
# 12           nrm_U_one_over_p_rbf       0.75  12.200000      100.0
# 13           ipr_V_one_over_p_rbf       0.75  12.511111      100.0
# 14  ipr_U_bootstrap_mse_laplacian       0.75  13.622222      100.0
# 15        nrm_U_bootstrap_mse_rbf       0.75  14.200000      100.0
# 16  nrm_U_bootstrap_mse_laplacian       0.75  14.288889      100.0
# 17        nrm_V_bootstrap_var_rbf       0.75  14.311111      100.0
# 18  nrm_V_bootstrap_var_laplacian       0.75  15.466667      100.0
# 19           nrm_V_grid_laplacian       0.75  15.511111      100.0
# 20  nrm_V_bootstrap_mse_laplacian       0.75  16.466667      100.0
# 21        nrm_V_bootstrap_mse_rbf       0.75  16.911111      100.0
# 22  nrm_U_bootstrap_var_laplacian       0.75  20.088889      100.0
# 23        ipr_U_bootstrap_var_rbf       0.75  20.088889      100.0
# 24  ipr_U_bootstrap_var_laplacian       0.75  20.377778      100.0
# 25        nrm_U_bootstrap_var_rbf       0.75  22.133333      100.0
# 26        ipr_V_bootstrap_mse_rbf       0.75  22.911111      100.0
# 27                 ipr_V_grid_rbf       0.75  25.688889      100.0
# 28  ipr_V_bootstrap_mse_laplacian       0.75  25.911111      100.0
# 29        ipr_V_bootstrap_var_rbf       0.75  26.622222      100.0
# 30           ipr_V_grid_laplacian       0.75  28.022222      100.0
# 31  ipr_V_bootstrap_var_laplacian       0.75  28.044444      100.0

# %% [markdown]
# ### Figure 5

# %%
plot_mse(df_mse, ['U', 'V'], ['rbf', 'laplacian'], ['ipr'])

# %% [markdown]
# ## Dimension

# %%
df_mse = pd.read_csv('results/results_dimension_mse_new.csv', index_col=0)

# %% [markdown]
# ### Figure 6

# %%
plot_mse(df_mse, ['U'])

# %% [markdown]
# ### Figure 7

# %%
plot_mse(df_mse, ['V'])

# %% [markdown]
# ### Figure 8

# %%
plot_mse(df_mse, ['U', 'V'], estimator=['ipr'])

# %% [markdown]
# ## Heavy tail distribution

# %%
df_mse = pd.read_csv('results/results_heavy_tail_mse_new.csv', index_col=0)

# %% [markdown]
# ### Figure 9

# %%
plot_mse(df_mse, ['U', 'V'], col_wrap=4)

# %% [markdown]
# # TIME

# %%
df = pd.read_csv('results/results_standard_all.csv', index_col=0)

# %%
df['log_time'] = np.log(df['time'])

# %%
df = df.sort_values(by=["pi_target", "sim_scenario"])
df['facet_blocks'] = df['sim_scenario'] + ", pi_target = " + df['pi_target'].astype(str)

# %%
g = sns.catplot(data=df,
    x="x",  
    y="log_time",              
    hue="method_name",
    palette='tab20',
    col="facet_blocks",         
    kind="bar",
    height=10,
    # aspect=1.2,
    sharey=False,
    sharex=False,
    col_wrap=3
)
g.set_titles("{col_name}")
plt.show()

# %%
# df_time = df[(df['sim_scenario'] == 'sim_par_1') & (df['pi_target'] == 0.25)]

# %%
# df_time = df_time[['time', 'gamma_selection_name', 'type', 'n_target', 'estimator', 'kernel']].groupby(['gamma_selection_name', 'type', 'n_target', 'estimator', 'kernel']).agg('mean').reset_index()

# %%
# df_time['my_time'] = np.nan
# df_time.loc[df_time['gamma_selection_name'] == 'one_over_p', 'my_time'] = 1
# df_time.loc[df_time['gamma_selection_name'] == 'grid', 'my_time'] = 13 + 1
# df_time.loc[df_time['gamma_selection_name'] == 'bootstrap_var', 'my_time'] = 13*50 + 1
# df_time.loc[df_time['gamma_selection_name'] == 'bootstrap_mse', 'my_time'] = 13*50 + 50 + 1
# df_time.loc[df_time['gamma_selection_name'] == 'distance', 'my_time'] = 13 + 1

# %%
# for i in range(len(df_time)):
#     df_time['my_time'] = df_time['my_time']

# %%
# df_time['my_time'] = df_time['my_time']*0.03903

# %%
# df_time.loc[df_time['gamma_selection_name'] == 'one_over_p', 'time']

# %%
# sns.scatterplot(df_time, x='my_time', y='time')
